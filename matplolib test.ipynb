# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
entradas = [1,22,14,25,13,30,10,44,60,70,20]

# %%
plt.plot(entradas,color='purple',linestyle='dashed',
         markerfacecolor='yellow',markersize=12)
